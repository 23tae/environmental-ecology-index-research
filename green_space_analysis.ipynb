# %%
import pandas as pd

# %%
df = pd.read_csv('./data/녹지현황(2022).csv', encoding='utf-8', skiprows=1)

# %%
selected_columns = df[['구분별(2)', '합계', '합계.1']]

# %%
selected_columns.columns = ['자치구명', '개소', '면적']

# %%
selected_columns.drop(index=[0, 1, 27, 28], inplace=True)
# Out:
# /var/folders/qr/d0tz05096cq7wtbf54br3qsw0000gn/T/ipykernel_31226/497738570.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_columns.drop(index=[0, 1, 27, 28], inplace=True)

# %%
selected_columns
# Out:
#     자치구명   개소         면적
# 2    종로구  680   228451.0
# 3     중구  387   222277.0
# 4    용산구  346   354568.0
# 5    성동구  413   311512.2
# 6    광진구  250   290567.0
# 7   동대문구  322   421368.0
# 8    중랑구  294   539974.0
# 9    성북구  362   412861.0
# 10   강북구  214   139129.0
# 11   도봉구  324   266372.0
# 12   노원구  415   673507.0
# 13   은평구  257   410163.0
# 14  서대문구  241   254797.0
# 15   마포구  421   886405.3
# 16   양천구  254   481862.0
# 17   강서구  360  1152971.0
# 18   구로구  413   681696.0
# 19   금천구  213   421352.0
# 20  영등포구  413   803487.0
# 21   동작구  251   283028.1
# 22   관악구  300   252680.0
# 23   서초구  323  1447114.0
# 24   강남구  423  2002549.5
# 25   송파구  340  1001473.5
# 26   강동구  301   606939.4
