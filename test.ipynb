# %%
import pandas as pd

# %%
df = pd.read_csv('./data/서울특별시 건축물대장 정보(2022년).csv', encoding='cp949', nrows=100, sep=';')

# %%
df2 = pd.read_csv('./data/서울특별시 건축물대장 정보(2022년) 2.csv', encoding='cp949', nrows=100, sep=';')

# %%
df
# Out:
#    mgm_bldrgst_pk mgm_upper_bldrgst_pk regstr_gb_cd regstr_kind_cd sigungu_cd  \
# 0     11110-75495          11110-20425           집합            전유부        종로구
# 1     11470-60089           11470-2769           집합            전유부        양천구
# 2     11170-50025           11170-9414           집합            전유부        용산구
# 3     11470-60070           11470-2769           집합            전유부        양천구
# 4     11170-49651           11170-9414           집합            전유부        용산구
# ..            ...                  ...          ...            ...        ...
# 95    11530-97288          11530-10578           집합            전유부        구로구
# 96    11170-49718           11170-9414           집합            전유부        용산구
# 97   11530-110030           11530-2795           집합            전유부        구로구
# 98    11170-49719           11170-9414           집합            전유부        용산구
# 99    11470-60087           11470-2769           집합            전유부        양천구
#
# ...

# %%
df2
# Out:
#    mgm_bldrgst_pk mgm_upper_bldrgst_pk regstr_gb_cd regstr_kind_cd sigungu_cd  \
# 0     11110-75495          11110-20425           집합            전유부        종로구
# 1     11470-60089           11470-2769           집합            전유부        양천구
# 2     11170-50025           11170-9414           집합            전유부        용산구
# 3     11470-60070           11470-2769           집합            전유부        양천구
# 4     11170-49651           11170-9414           집합            전유부        용산구
# ..            ...                  ...          ...            ...        ...
# 95    11530-97288          11530-10578           집합            전유부        구로구
# 96    11170-49718           11170-9414           집합            전유부        용산구
# 97   11530-110030           11530-2795           집합            전유부        구로구
# 98    11170-49719           11170-9414           집합            전유부        용산구
# 99    11470-60087           11470-2769           집합            전유부        양천구
#
# ...
