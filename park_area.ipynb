# %%
import pandas as pd

# %%
df = pd.read_csv('./data/서울시_공원통계(2022).csv', encoding='utf-8')

# %%
park = df[['자치구별(2)', '2022.2']]

# %%
park.drop(index=range(5), inplace=True)
park.drop(index=30, inplace=True)
park.columns = ['자치구명', '공원면적']
# Out:
# /var/folders/qr/d0tz05096cq7wtbf54br3qsw0000gn/T/ipykernel_32401/1430340065.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   park.drop(index=range(5), inplace=True)
# /var/folders/qr/d0tz05096cq7wtbf54br3qsw0000gn/T/ipykernel_32401/1430340065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   park.drop(index=30, inplace=True)

# %%
park
# Out:
#     자치구명     공원면적
# 5    종로구  11434.6
# 6     중구   3206.2
# 7    용산구   1774.0
# 8    성동구   3083.8
# 9    광진구   3459.8
# 10  동대문구   1215.4
# 11   중랑구   5229.0
# 12   성북구   8526.7
# 13   강북구  14495.4
# 14   도봉구  10151.0
# 15   노원구  14741.6
# 16   은평구  14400.1
# 17  서대문구   5106.2
# 18   마포구   4569.4
# 19   양천구   3049.6
# 20   강서구   4518.3
# 21   구로구   3712.7
# 22   금천구   2774.4
# 23  영등포구   3003.0
# 24   동작구   4368.2
# 25   관악구  12485.2
# 26   서초구  15072.0
# 27   강남구   7794.1
# 28   송파구   4776.8
# 29   강동구   3406.5
